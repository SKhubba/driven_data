# %%
import pandas as pd
from statsmodels.imputation import mice

# %%
# import the raw training data
from data_munge import a_i_train, a_h_train, b_i_train, b_h_train, c_i_train, c_h_train

# import the raw test data
from data_munge import a_i_test, a_h_test, b_i_test, b_h_test, c_i_test, c_h_test

# import the preprocessed data
from data_munge import aX_h_train, ay_h_train, bX_h_train, by_h_train, cX_h_train, cy_h_train
from data_munge import aX_i_train, ay_i_train, bX_i_train, by_i_train, cX_i_train, cy_i_train

# %% [markdown]
# Note that only B's household and individual, and A's individual data have NaNs.

# %%
True in a_i_train.isnull().any(axis=1).values
# Out:
# True

# %%
True in a_h_train.isnull().any(axis=1).values
# Out:
# False

# %%
True in b_i_train.isnull().any(axis=1).values
# Out:
# True

# %%
True in b_h_train.isnull().any(axis=1).values
# Out:
# True

# %%
True in c_i_train.isnull().any(axis=1).values
# Out:
# False

# %%
True in c_h_train.isnull().any(axis=1).values
# Out:
# False

# %%
True in bX_i_train.isnull().any(axis=1).values
# Out:
# True

# %% [markdown]
# StatsModels has a nice multiple imputation packages

# %%
imp = mice.MICEData(bX_i_train)

# %%
True in imp.data.isnull().any(axis=1).values
# Out:
# False

# %%
imp.data['BoxViLPz']
# Out:
# 0        0.125074
# 1        0.125074
# 2       -1.835997
# 3        0.125074
# 4        0.125074
# 5        0.125074
# 6        0.125074
# 7        0.125074
# 8       -1.182306
# 9        0.125074
# 10       1.105609
# 11       1.105609
# 12       0.125074
# 13       0.125074
# 14       0.125074
# 15       0.125074
# 16       0.125074
# 17       0.778764
# 18       0.125074
# 19       0.125074
# 20      -0.855461
# 21       1.432455
# 22       0.778764
# 23       0.778764
# 24       0.125074
# 25       0.125074
# 26       0.125074
# 27       0.125074
# 28       0.778764
# 29       0.125074
#            ...
# 20222   -1.182306
# 20223    0.125074
# 20224    0.125074
# 20225    0.125074
# 20226    0.125074
# 20227    0.125074
# 20228    0.125074
# 20229    0.125074
# 20230    0.125074
# 20231    0.125074
# 20232   -0.528616
# 20233    0.778764
# 20234    0.125074
# 20235    0.125074
# 20236    0.125074
# 20237    0.125074
# 20238    0.125074
# 20239    0.125074
# 20240    0.125074
# 20241    0.125074
# 20242    0.125074
# 20243    0.125074
# 20244    0.125074
# 20245    0.125074
# 20246    0.125074
# 20247    0.125074
# 20248    0.125074
# 20249    0.125074
# 20250    0.125074
# 20251    0.125074
# Name: BoxViLPz, Length: 20252, dtype: float64

# %%
True in a_h_train.isnull().any(axis=1)
# Out:
# False

# %%
True in aX_i_train.isnull().any(axis=1)
# Out:
# False

# %%
b_h_train
# Out:
#       RzaXNcgd LfWEhutI jXOqJdNL  wJthinfa PTLgvdlQ  ZvEApWrk euTESpHe  \
# id
# 57071    zTghO    pYfmQ    lNhMv        42    RQnVj       103    jpSeC
# 18973    zTghO    pYfmQ    lNhMv        34    iuxWN        -2    OLVWN
# 20151    zTghO    pYfmQ    lNhMv        34    iuxWN       313    OMRWa
# 5730     zTghO    pYfmQ    lNhMv        58    iuxWN       138    jpSeC
# 35033    zTghO    pYfmQ    lNhMv       122    iuxWN        68    OLVWN
# 51376    WoQQq    pYfmQ    lNhMv         2    iuxWN        33    OLVWN
# 35249    zTghO    pYfmQ    lNhMv        10    iuxWN        33    OLVWN
# 54947    zTghO    pYfmQ    lNhMv        66    iuxWN       208    OLVWN
# 60784    zTghO    pYfmQ    lNhMv         2    iuxWN       243    OLVWN
# 97285    zTghO    pYfmQ    lNhMv        66    iuxWN        61    OLVWN
# 36730    zTghO    pYfmQ    lNhMv        66    RQnVj        33    OMRWa
# 19086    zTghO    pYfmQ    lNhMv        58    iuxWN        -2    OLVWN
# 33112    zTghO    pYfmQ    lNhMv        42    iuxWN        -2    OLVWN
# 930      zTghO    pYfmQ    lNhMv        42    iuxWN       103    OLVWN
# 84922    zTghO    pYfmQ    yLRKG        50    iuxWN        68    OMRWa
# 40553    zTghO    pYfmQ    lNhMv        58    iuxWN        33    OLVWN
# 52673    zTghO    pYfmQ    lNhMv        34    iuxWN        -2    OMRWa
# 51407    zTghO    pYfmQ    lNhMv         2    iuxWN        68    OLVWN
# 32338    zTghO    pYfmQ    lNhMv        42    iuxWN        68    XJugP
# 86848    zTghO    pYfmQ    lNhMv        66    iuxWN        40    OMRWa
# 3724     zTghO    pYfmQ    lNhMv        18    iuxWN       103    OLVWN
# 1938     zTghO    pYfmQ    lNhMv        26    iuxWN        -2    OLVWN
# 51789    zTghO    pYfmQ    lNhMv        18    iuxWN        -2    OLVWN
# 50445    zTghO    pYfmQ    lNhMv        10    iuxWN       278    OLVWN
# 29202    zTghO    pYfmQ    yLRKG        26    iuxWN        33    jpSeC
# 11711    zTghO    pYfmQ    lNhMv        34    iuxWN       103    OLVWN
# 693      zTghO    pYfmQ    lNhMv        34    iuxWN       138    OLVWN
# 34020    zTghO    pYfmQ    lNhMv        90    RQnVj       208    OMRWa
# 41695    zTghO    pYfmQ    lNhMv        34    iuxWN       173    OMRWa
# 147      zTghO    pYfmQ    lNhMv        42    iuxWN       103    OMRWa
# ...        ...      ...      ...       ...      ...       ...      ...
# 68697    zTghO    pYfmQ    lNhMv        42    iuxWN       103    jpSeC
# 33723    zTghO    pYfmQ    lNhMv        26    RQnVj       138    OLVWN
# 23301    zTghO    pYfmQ    lNhMv        26    iuxWN        33    OLVWN
# 96225    zTghO    pYfmQ    lNhMv        34    iuxWN        33    nHrVb
# 33482    zTghO    pYfmQ    lNhMv        82    iuxWN        -2    OLVWN
# 32798    zTghO    pYfmQ    yLRKG        58    iuxWN        33    OMRWa
# 18335    zTghO    BucnG    lNhMv        26    iuxWN        33    OLVWN
# 73496    zTghO    pYfmQ    lNhMv        66    iuxWN        68    OMRWa
# 77405    zTghO    pYfmQ    lNhMv        50    iuxWN        19    OLVWN
# 41479    zTghO    pYfmQ    yLRKG        34    iuxWN       278    OMRWa
# 25631    zTghO    pYfmQ    lNhMv        34    iuxWN        68    OLVWN
# 728      zTghO    pYfmQ    lNhMv        50    iuxWN        -2    OLVWN
# 5980     zTghO    pYfmQ    lNhMv        58    iuxWN        68    OMRWa
# 26041    zTghO    pYfmQ    lNhMv        50    iuxWN       208    OLVWN
# 15111    zTghO    pYfmQ    lNhMv        58    iuxWN       208    OMRWa
# 39675    zTghO    pYfmQ    lNhMv        42    iuxWN       103    OMRWa
# 95500    zTghO    pYfmQ    lNhMv        50    iuxWN       418    OLVWN
# 43358    zTghO    pYfmQ    lNhMv        18    iuxWN       103    OLVWN
# 22674    zTghO    pYfmQ    yLRKG        42    iuxWN       138    OLVWN
# 72606    zTghO    pYfmQ    lNhMv        42    iuxWN       138    nHrVb
# 99962    zTghO    pYfmQ    lNhMv        74    iuxWN        68    OMRWa
# 92677    zTghO    pYfmQ    yLRKG        10    iuxWN        68    OLVWN
# 29121    zTghO    pYfmQ    lNhMv        58    iuxWN       173    OLVWN
# 25906    zTghO    pYfmQ    lNhMv        34    iuxWN        -2    OMRWa
# 15572    zTghO    pYfmQ    yLRKG       106    iuxWN        33    OMRWa
# 63129    zTghO    pYfmQ    lNhMv        74    iuxWN       138    OLVWN
# 73304    zTghO    BucnG    lNhMv        18    iuxWN        68    OLVWN
# 46698    zTghO    pYfmQ    lNhMv        58    iuxWN        68    OLVWN
# 41387    zTghO    pYfmQ    lNhMv        34    iuxWN        68    OLVWN
# 4923     zTghO    BucnG    lNhMv        26    BALIg        -2    OLVWN
#
#       bDVMMSYY aSzMhjgD ZehDbxxy   ...   YVMuyCUV AZVtosGB toZzckhe BkiXyuSp  \
# id                                 ...
# 57071    FDqwJ    rxJJI    IbWRL   ...      nZcTi    pdvWY    LLuZj    qpzpO
# 18973    FDqwJ    ufugi    IbWRL   ...      nZcTi    XrijK    LLuZj    qpzpO
# 20151    FDqwJ    rxJJI    IbWRL   ...      nZcTi    FEjSW    lmjln    qpzpO
# 5730     FDqwJ    rxJJI    IbWRL   ...      nZcTi    XrijK    lmjln    ZZzXr
# 35033    FDqwJ    rxJJI    IbWRL   ...      nZcTi    CRHYU    lmjln    qpzpO
# 51376    FDqwJ    rxJJI    IbWRL   ...      nZcTi    DLwsh    lmjln    ZZzXr
# 35249    iirrf    ufugi    IbWRL   ...      nZcTi    XrijK    LLuZj    qpzpO
# 54947    FDqwJ    rxJJI    IbWRL   ...      DvWFi    FEjSW    LLuZj    ZZzXr
# 60784    YJqBG    rxJJI    IbWRL   ...      nZcTi    FEjSW    lmjln    ZZzXr
# 97285    FDqwJ    ufugi    IbWRL   ...      nZcTi    DLwsh    lmjln    qpzpO
# 36730    FDqwJ    rxJJI    IbWRL   ...      nZcTi    pdvWY    lmjln    qpzpO
# 19086    iirrf    rxJJI    IbWRL   ...      nZcTi    JGoxG    lmjln    qpzpO
# 33112    FDqwJ    rxJJI    IbWRL   ...      DvWFi    DLwsh    lmjln    qpzpO
# 930      FDqwJ    ufugi    IbWRL   ...      nZcTi    pdvWY    lmjln    ZZzXr
# 84922    FDqwJ    rxJJI    IbWRL   ...      nZcTi    DLwsh    LLuZj    qpzpO
# 40553    FDqwJ    rxJJI    IbWRL   ...      nZcTi    DLwsh    lmjln    qpzpO
# 52673    FDqwJ    rxJJI    IbWRL   ...      nZcTi    DLwsh    lmjln    ZZzXr
# 51407    FDqwJ    ufugi    IbWRL   ...      nZcTi    DLwsh    lmjln    qpzpO
# 32338    iirrf    ufugi    IbWRL   ...      nZcTi    pdvWY    lmjln    qpzpO
# 86848    FDqwJ    rxJJI    IbWRL   ...      nZcTi    XrijK    LLuZj    qpzpO
# 3724     iirrf    rxJJI    IbWRL   ...      nZcTi    XrijK    LLuZj    ZZzXr
# 1938     iirrf    rxJJI    IbWRL   ...      nZcTi    XrijK    lmjln    qpzpO
# 51789    FDqwJ    ufugi    IbWRL   ...      nZcTi    SiLcr    lmjln    ZZzXr
# 50445    FDqwJ    rxJJI    IbWRL   ...      DvWFi    pdvWY    lmjln    qpzpO
# 29202    iirrf    ufugi    IbWRL   ...      nZcTi    pdvWY    LLuZj    qpzpO
# 11711    FDqwJ    rxJJI    IbWRL   ...      nZcTi    SiLcr    lmjln    qpzpO
# 693      FDqwJ    rxJJI    IbWRL   ...      nZcTi    JGoxG    LLuZj    ZZzXr
# 34020    FDqwJ    rxJJI    IbWRL   ...      nZcTi    FEjSW    lmjln    qpzpO
# 41695    FDqwJ    ufugi    IbWRL   ...      nZcTi    DLwsh    LLuZj    qpzpO
# 147      FDqwJ    ufugi    IbWRL   ...      DvWFi    pdvWY    LLzTd    qpzpO
# ...        ...      ...      ...   ...        ...      ...      ...      ...
# 68697    FDqwJ    rxJJI    IbWRL   ...      nZcTi    SiLcr    LLuZj    qpzpO
# 33723    iirrf    rxJJI    IbWRL   ...      nZcTi    DLwsh    lmjln    qpzpO
# 23301    FDqwJ    ufugi    IbWRL   ...      nZcTi    XrijK    LLuZj    qpzpO
# 96225    FDqwJ    rxJJI    IbWRL   ...      nZcTi    XrijK    lmjln    ZZzXr
# 33482    FDqwJ    rxJJI    IbWRL   ...      nZcTi    XrijK    LLuZj    qpzpO
# 32798    iirrf    rxJJI    IbWRL   ...      nZcTi    DLwsh    lmjln    qpzpO
# 18335    FDqwJ    rxJJI    IbWRL   ...      nZcTi    XrijK    LLuZj    ZZzXr
# 73496    FDqwJ    rxJJI    IbWRL   ...      DvWFi    XrijK    LLuZj    qpzpO
# 77405    FDqwJ    rxJJI    IbWRL   ...      DvWFi    JGoxG    lmjln    qpzpO
# 41479    FDqwJ    rxJJI    IbWRL   ...      nZcTi    pdvWY    lmjln    ZZzXr
# 25631    FDqwJ    rxJJI    IbWRL   ...      nZcTi    XrijK    lmjln    ZZzXr
# 728      iirrf    rxJJI    IbWRL   ...      nZcTi    SiLcr    lmjln    qpzpO
# 5980     iirrf    ufugi    IbWRL   ...      nZcTi    XrijK    lmjln    qpzpO
# 26041    iirrf    rxJJI    IbWRL   ...      nZcTi    pdvWY    lmjln    qpzpO
# 15111    FDqwJ    rxJJI    IbWRL   ...      nZcTi    pdvWY    LLuZj    qpzpO
# 39675    FDqwJ    rxJJI    IbWRL   ...      nZcTi    FEjSW    lmjln    ZZzXr
# 95500    FDqwJ    ufugi    IbWRL   ...      DvWFi    pdvWY    LLuZj    qpzpO
# 43358    FDqwJ    rxJJI    IbWRL   ...      nZcTi    XrijK    lmjln    qpzpO
# 22674    FDqwJ    rxJJI    IbWRL   ...      nZcTi    DLwsh    lmjln    qpzpO
# 72606    FDqwJ    rxJJI    IbWRL   ...      nZcTi    pdvWY    lmjln    qpzpO
# 99962    iirrf    ufugi    IbWRL   ...      nZcTi    pdvWY    lmjln    qpzpO
# 92677    FDqwJ    rxJJI    IbWRL   ...      nZcTi    XAeTz    LLuZj    qpzpO
# 29121    FDqwJ    rxJJI    IbWRL   ...      nZcTi    DLwsh    lmjln    qpzpO
# 25906    yaTix    rxJJI    IbWRL   ...      DvWFi    DLwsh    LLuZj    qpzpO
# 15572    FDqwJ    rxJJI    IbWRL   ...      DvWFi    FEjSW    LLzTd    qpzpO
# 63129    FDqwJ    rxJJI    IbWRL   ...      nZcTi    XrijK    LLzTd    ZZzXr
# 73304    FDqwJ    rxJJI    IbWRL   ...      nZcTi    SiLcr    LLuZj    qpzpO
# 46698    iirrf    rxJJI    IbWRL   ...      nZcTi    pdvWY    lmjln    ZZzXr
# 41387    FDqwJ    rxJJI    IbWRL   ...      nZcTi    SiLcr    LLuZj    ZZzXr
# 4923     FDqwJ    rxJJI    IbWRL   ...      nZcTi    DLwsh    lmjln    ZZzXr
#
#       ggucvVUs VMvwrYds VlNidRNP rljjAmaN ChbSWYhO country
# id
# 57071    kZRgh    VwGOP    DScEf    SKBnS    Enull       B
# 18973    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 20151    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 5730     kZRgh    VwGOP    ZwQQe    SKBnS    Enull       B
# 35033    kZRgh    VwGOP    WFgZH    SKBnS    Enull       B
# 51376    mVkRU    VwGOP    JOdCB    SKBnS    OPpaN       B
# 35249    mVkRU    VwGOP    JOdCB    SKBnS    Enull       B
# 54947    kZRgh    VwGOP    VmrpP    SKBnS    Enull       B
# 60784    mVkRU    VwGOP    JOdCB    EBZee    Enull       B
# 97285    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 36730    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 19086    kZRgh    VwGOP    yvOdU    SKBnS    Enull       B
# 33112    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 930      kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 84922    kZRgh    VwGOP    yvOdU    EBZee    Enull       B
# 40553    kZRgh    VwGOP    DScEf    SKBnS    Enull       B
# 52673    kZRgh    VwGOP    ZwQQe    SKBnS    Enull       B
# 51407    kZRgh    VwGOP    JOdCB    SKBnS    fWqni       B
# 32338    mVkRU    VwGOP    jRdRl    EBZee    Enull       B
# 86848    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 3724     cMmai    VwGOP    jRdRl    EBZee    Enull       B
# 1938     mVkRU    VwGOP    JOdCB    SKBnS    Enull       B
# 51789    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 50445    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 29202    kZRgh    VwGOP    JOdCB    akDoa    Enull       B
# 11711    mVkRU    VwGOP    JOdCB    SKBnS    Enull       B
# 693      mVkRU    VwGOP    JOdCB    EBZee    Enull       B
# 34020    kZRgh    VwGOP    JOdCB    aGlDf    Enull       B
# 41695    kZRgh    VwGOP    yvOdU    gPPdN    Enull       B
# 147      kZRgh    VwGOP    JOdCB    fEsQq    Enull       B
# ...        ...      ...      ...      ...      ...     ...
# 68697    kZRgh    VwGOP    ZwQQe    gPPdN    Enull       B
# 33723    kZRgh    VwGOP    ZwQQe    SKBnS    Enull       B
# 23301    kZRgh    VwGOP    ZwQQe    SKBnS    Enull       B
# 96225    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 33482    kZRgh    VwGOP    yvOdU    SKBnS    Enull       B
# 32798    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 18335    mVkRU    VwGOP    JOdCB    akDoa    Enull       B
# 73496    kZRgh    VwGOP    JOdCB    gPPdN    Enull       B
# 77405    kZRgh    VwGOP    yvOdU    SKBnS    Enull       B
# 41479    kZRgh    VwGOP    jRdRl    gPPdN    Enull       B
# 25631    mVkRU    VwGOP    VmrpP    fEsQq    Enull       B
# 728      kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 5980     kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 26041    kZRgh    VwGOP    ZwQQe    SKBnS    Enull       B
# 15111    kZRgh    VwGOP    VmrpP    SKBnS    Enull       B
# 39675    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 95500    kZRgh    VwGOP    jRdRl    SKBnS    Enull       B
# 43358    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 22674    kZRgh    VwGOP    yvOdU    SKBnS    Enull       B
# 72606    ahEsG    VwGOP    JOdCB    gPPdN    Enull       B
# 99962    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 92677    kZRgh    VwGOP    JOdCB    gPPdN    Enull       B
# 29121    kZRgh    VwGOP    JOdCB    SKBnS    Enull       B
# 25906    kZRgh    VwGOP    ZwQQe    SKBnS    Enull       B
# 15572    kZRgh    VwGOP    yvOdU    SKBnS    Enull       B
# 63129    kZRgh    VwGOP    yvOdU    SKBnS    Enull       B
# 73304    mVkRU    VwGOP    jRdRl    EBZee    Enull       B
# 46698    ahEsG    VwGOP    jRdRl    gPPdN    Enull       B
# 41387    mVkRU    VwGOP    JOdCB    EBZee    Enull       B
# 4923     kZRgh    VwGOP    ZwQQe    fEsQq    Enull       B
#
# [3255 rows x 442 columns]
